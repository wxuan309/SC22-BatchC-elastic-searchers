COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","FULL-SIZE","MID-SIZE","FULL-SIZE","COMPACT","SUBCOMPACT","COMPACT","COMPACT","FULL-SIZE","FULL-SIZE","FULL-SIZE","FULL-SIZE","COMPACT","MID-SIZE","FULL-SIZE","FULL-SIZE","FULL-SIZE","MID-SIZE","MID-SIZE","COMPACT","COMPACT","SUBCOMPACT","SUBCOMPACT","COMPACT","COMPACT","SUV - SMALL","SUV - SMALL","SUV - SMALL","SUV - SMALL","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","TWO-SEATER","TWO-SEATER","TWO-SEATER","TWO-SEATER","TWO-SEATER","SUV - STANDARD","SUV - STANDARD","SUV - SMALL","SUV - SMALL","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","STATION WAGON - SMALL","STATION WAGON - SMALL","STATION WAGON - SMALL","STATION WAGON - SMALL","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","STATION WAGON - SMALL","STATION WAGON - SMALL","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","SUV - STANDARD","FULL-SIZE","FULL-SIZE","FULL-SIZE","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","COMPACT","TWO-SEATER","TWO-SEATER","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","MID-SIZE","SUV - SMALL","SUV - SMALL","SUV - SMALL","SUV - SMALL","SUV - SMALL","SUV - SMALL","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - CARGO","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","VAN - PASSENGER","FULL-SIZE","FULL-SIZE","FULL-SIZE","FULL-SIZE","MID-SIZE","MID-SIZE","SUV - SMALL","SUV - SMALL","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK - STANDARD","PICKUP TRUCK  ...

# %%
df.head()
# Out:
#     Make       Model Vehicle Class  Engine Size(L)  Cylinders Transmission  \
# 0  ACURA         ILX       COMPACT             2.0          4          AS5
# 1  ACURA         ILX       COMPACT             2.4          4           M6
# 2  ACURA  ILX HYBRID       COMPACT             1.5          4          AV7
# 3  ACURA     MDX 4WD   SUV - SMALL             3.5          6          AS6
# 4  ACURA     RDX AWD   SUV - SMALL             3.5          6          AS6
#
#   Fuel Type  Fuel Consumption City (L/100 km)  \
# 0         Z                               9.9
# 1         Z                              11.2
# 2         Z                               6.0
# 3         Z                              12.7
# 4         Z                              12.1
#
#    Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                              6.7                               8.5
# 1                              7.7                               9.6
# 2                              5.8                               5.9
# 3                              9.1                              11.1
# 4                              8.7                              10.6
#
#    Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                           33                  196
# 1                           29                  221
# 2                           48                  136
# 3                           25                  255
# 4                           27                  244

# %%
#df.loc[df['Make'] == 'VOLVO', 'Model'].unique()
df['Fuel Type'].unique()
# Out:
# array(['Z', 'D', 'X', 'E', 'N'], dtype=object)

# %%
#df = df.drop(columns = ['Make', 'Model', 'Vehicle Class','Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)'])
df = df.drop(columns = ['Vehicle Class','Engine Size(L)', 'Cylinders', 'Transmission', 'Fuel Consumption City (L/100 km)', 'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)', 'Fuel Consumption Comb (mpg)'])
df.head()

#df.loc[df['Make'] == 'BUICK', 'Model'].unique()
#df["Make"].unique()
# Out:
#     Make       Model Fuel Type  CO2 Emissions(g/km)
# 0  ACURA         ILX         Z                  196
# 1  ACURA         ILX         Z                  221
# 2  ACURA  ILX HYBRID         Z                  136
# 3  ACURA     MDX 4WD         Z                  255
# 4  ACURA     RDX AWD         Z                  244

# %%
#from sklearn.model_selection import train_test_split

#col_category = ['Make', 'Model', 'Fuel Type']
#for col in col_category:
#    df= pd.concat([df.drop(col, axis=1), pd.get_dummies(df[col], prefix=col, prefix_sep='_')], axis=1)
# define the input_columns and target variables
#input_columns = df.loc[:, df.columns != "CO2 Emissions(g/km)"]
#target = df["CO2 Emissions(g/km)"]
#x_train, x_test, y_train, y_test = train_test_split(input_columns, target, test_size=0.2)

# %%
#from sklearn.model_selection import GridSearchCV
#from sklearn.model_selection import RepeatedKFold

#SVR parameters
#n_alphas = [10, 100, 200]
#max_iter = [50, 1000, 2000]
#eps = [1e-1, 1e-2, 1e-4]
#grid = dict(n_alphas=n_alphas, max_iter=max_iter, eps=eps)
#MODEL=LassoCV()
# parameter saved in a dictionary

#PARAMETER = {'n_alphas': [10, 100, 200],
#             'max_iter': [50, 1000, 2000],
#             'eps': [1e-1, 1e-2, 1e-4]}
# implement grid search cv
#cvFold = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
#gs_lasso = GridSearchCV(estimator=MODEL, param_grid=grid, n_jobs=-1, cv=cvFold, scoring="neg_mean_squared_error")
# fit the models
#gs_res = gs_lasso.fit(x_train, y_train)
# print out the best parameter
#print(gs_res.best_params_)

# %%
# save the model into a variable
#lasso = LassoCV(n_alphas= 20, max_iter= 3000, eps= 0.0001)
# fit the model
#lasso.fit(x_train, y_train)
# predict the value: for the predict, just use the x_test
# the predict function will be using our testing dataset to predict our co2 emission
#y_hat = lasso.predict(x_test)

#lasso.score(x_test, y_test)

# %%
#calculate MSE
#total_squared_error = (np.sum((y_test - y_hat)**2)) #get the sum of all the errors (error = what we want (y_test) - what we predicted (y_hat))
#mean_squared_error = total_squared_error/len(y_test) #divide this by how many rows/observations we have 
#print(mean_squared_error)

#calculate RMSE
#rmse = math.sqrt(mean_squared_error)
#print(rmse)

# normalize it
#normrmse = rmse/(max(df['CO2 Emissions(g/km)'])-min(df['CO2 Emissions(g/km)']))
#print(normrmse)
